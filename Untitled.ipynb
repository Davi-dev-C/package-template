# %%
from image_processing2.utils import io, plot
from image_processing2.processing import combination, transformation

# %%
image1 = io.read_image('C:/Users/davih/Pictures/MEmu_Photo/vermelho.jpg')
image2 = io.read_image('C:/Users/davih/Pictures/MEmu_Photo/rosas.jpg')

# %%
plot.plot_image(image1)
plot.plot_image(image2)

# %%
result_image = combination.transfer_histogram(image2, image1)
plot.plot_result(image1, image2, result_image)
# Out:
# C:\Users\davih\Documents\DIO\aulas_python\arquivos-py\DESAFIOS_DE_PROJETOS\image_processing_package2\image_processing2\processing\combination.py:18: FutureWarning: `multichannel` is a deprecated argument name for `match_histograms`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   matched_image = match_histograms(image1, image2, multichannel=True)
